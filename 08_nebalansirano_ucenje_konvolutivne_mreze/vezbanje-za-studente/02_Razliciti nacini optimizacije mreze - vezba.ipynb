# %% [markdown]
# Podsetnik: http://ml.matf.bg.ac.rs/readings/ml.pdf

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
import sklearn
import sklearn.datasets
import scipy.io

# %%
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import RMSprop
from keras.optimizers import Adam
from keras.optimizers import SGD
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from keras import backend as K

# %%
np.random.seed(7)

# %% [markdown]
# #### Skup podataka je preuzet sa kursa optimizacija ML algoritama sa platforme Coursera-a
#
# Podaci se ucitavaju pozivom funkcije load_2D_dataset()
#
# Redovi i kolone su obrnuti pa ih treba transponovati.

# %%
def load_2D_dataset():
    data = scipy.io.loadmat('data.mat')
    train_X = np.array(data['X']).T
    train_Y = data['y'].T
    test_X = data['Xval'].T
    test_Y = data['yval'].T

    colors = np.where(train_Y==0, 'blue', 'red')
    plt.scatter(train_X[0, :], train_X[1, :], c=colors.flatten(), s=40, cmap=plt.cm.Spectral)
    
    return train_X, train_Y, test_X, test_Y

# %%
x_train, y_train, x_test, y_test = load_2D_dataset()
x_train = x_train.T
y_train = y_train.T
x_test = x_test.T
y_test = y_test.T

# %% [markdown]
# ### Zadatak 1
#
# #### Napraviti sledeci model:
#
# #### Slojevi
# - I sloj: 50 neurona, aktivaciona funkcija: relu
# - II sloj: 25 neurona, aktivaciona funkcija: relu
# - izlazni sloj: 1 neuron, aktivaciona funkcija: sigmoid
#
# #### Detalji algoritma
# - Funkcija greske: srednjekvadratna greska
# - Algoritam: gradijentni spust
# - Metrika: tacnost
#
# #### Hiperparametri
# - Broj iteracija: 3000
# - Batch size: 16
#
# Ispisati tacnost ovog modela na trening i test skupu

# %%
K.clear_session()

# %% [markdown]
# ### Zadatak 2 (Dropout)
#
# Napraviti model koji je isti kao i prethodno napisan model, ali koji ima dropout:
# - Ulazni podaci: 0.1
# - I sloj: 0.7
# - II sloj: 0.3
#
# Ispisati tacnost na trening i test skupu za ova model.

# %%
K.clear_session()

# %% [markdown]
# ### Zadatak 3 (Early stopping)
#
# Napraviti model koji je isti kao i prvi model koji smo napravili, a koji dodatno koristi tehniku EarlyStopping.
#
# Dokumentacija: https://keras.io/callbacks/
#
# #### Argumenti za EarlyStopping
# - monitor: quantity to be monitored.
# - min_delta: minimum change in the monitored quantity to qualify as an improvement, i.e. an absolute change of less than min_delta, will count as no improvement.
# - patience: number of epochs with no improvement after which training will be stopped.
# - verbose: verbosity mode.
# - mode: one of {auto, min, max}. In min mode, training will stop when the quantity monitored has stopped decreasing; in max mode it will stop when the quantity monitored has stopped increasing; in auto mode, the direction is automatically inferred from the name of the monitored quantity.

# %%
K.clear_session()

# %% [markdown]
# ### Zadatak 4 (Early Stopping + Gradient Clipping)
#
# Dokumentacija: https://keras.io/optimizers/
#
# Kopirati prethodni model.
#
# Izmeniti ga tako da radi odsecanje gradijenata na vrednost 0.2
#
# Ispisati podatke o tacnosti modela na trening i test skupu
#
# #Napomena: clipvalue 0.5 na onom prvom modelu - (dugo traje, test acc 91%)

# %%
K.clear_session()
